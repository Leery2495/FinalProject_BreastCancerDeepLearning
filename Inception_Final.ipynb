# %%
# Standard Library Imports
import os
import itertools
import warnings
warnings.filterwarnings("ignore")

# Data Handling and Numerical Operations
import numpy as np
import pandas as pd
import kagglehub as kh

# Plotting Libraries
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
# !pip install visualkeras
import visualkeras as vk

# Model Building and Preprocessing
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Flatten, Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import get_file
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Model Evaluation and Metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, classification_report, roc_curve, auc, confusion_matrix


ddsm_path = kh.dataset_download("awsaf49/cbis-ddsm-breast-cancer-image-dataset")
print(ddsm_path)
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (11.3.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (2.0.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (1.3.19)
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset

# %% [markdown]
# # Data Preperation

# %%
df_meta = pd.read_csv(ddsm_path+'/csv/meta.csv')
df_meta.head()
# Out:
#                                    SeriesInstanceUID  \
# 0  1.3.6.1.4.1.9590.100.1.2.117041576511324414842...
# 1  1.3.6.1.4.1.9590.100.1.2.438738396107617880132...
# 2  1.3.6.1.4.1.9590.100.1.2.767416741131676463382...
# 3  1.3.6.1.4.1.9590.100.1.2.296931352612305599800...
# 4  1.3.6.1.4.1.9590.100.1.2.436657670120353100077...
#
#                                     StudyInstanceUID Modality  \
# 0  1.3.6.1.4.1.9590.100.1.2.229361142710768138411...       MG
# 1  1.3.6.1.4.1.9590.100.1.2.195593486612988388325...       MG
# 2  1.3.6.1.4.1.9590.100.1.2.257901172612530623323...       MG
# 3  1.3.6.1.4.1.9590.100.1.2.109468616710242115222...       MG
# 4  1.3.6.1.4.1.9590.100.1.2.380627129513562450304...       MG
#
#   SeriesDescription BodyPartExamined  SeriesNumber Collection  Visibility  \
# 0   ROI mask images           BREAST             1  CBIS-DDSM           1
# 1   ROI mask images           BREAST             1  CBIS-DDSM           1
# 2   ROI mask images           BREAST             1  CBIS-DDSM           1
# 3   ROI mask images           BREAST             1  CBIS-DDSM           1
# 4   ROI mask images           BREAST             1  CBIS-DDSM           1
#
#    ImageCount
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2

# %%
# load dicom info file
df_dicom = pd.read_csv(ddsm_path+'/csv/dicom_info.csv')
df_dicom.head()
# Out:
#                                            file_path  \
# 0  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
# 1  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24838...
# 2  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.26721...
# 3  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 4  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
#
#                                           image_path  AccessionNumber  \
# 0  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
# 1  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...              NaN
# 2  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.267213...              NaN
# 3  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
# 4  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
#
#    BitsAllocated  BitsStored BodyPartExamined  Columns  ContentDate  \
# 0             16          16           BREAST      351     20160426
# 1             16          16           BREAST     3526     20160426
# 2             16          16           BREAST     1546     20160503
# 3             16          16           BREAST       97     20160503
# 4              8           8      Left Breast     3104     20160503
#
#    ContentTime ConversionType  ...  \
# 0   131732.685            WSD  ...
# 1   143829.101            WSD  ...
# 2   111956.298            WSD  ...
# 3   115347.770            WSD  ...
# 4   115347.770            WSD  ...
#
#    SecondaryCaptureDeviceManufacturerModelName      SeriesDescription  \
# 0                                       MATLAB         cropped images
# 1                                       MATLAB  full mammogram images
# 2                                       MATLAB  full mammogram images
# 3                                       MATLAB         cropped images
# 4                                       MATLAB                    NaN
#
#                                    SeriesInstanceUID SeriesNumber  \
# 0  1.3.6.1.4.1.9590.100.1.2.129308726812851964007...            1
# 1  1.3.6.1.4.1.9590.100.1.2.248386742010678582309...            1
# 2  1.3.6.1.4.1.9590.100.1.2.267213171011171858918...            1
# 3  1.3.6.1.4.1.9590.100.1.2.381187369611524586537...            1
# 4  1.3.6.1.4.1.9590.100.1.2.381187369611524586537...            1
#
#   SmallestImagePixelValue  SpecificCharacterSet   StudyDate StudyID  \
# 0                   23078            ISO_IR 100  20160720.0    DDSM
# 1                       0            ISO_IR 100  20160720.0    DDSM
# 2                       0            ISO_IR 100  20160807.0    DDSM
# 3                   32298            ISO_IR 100  20170829.0    DDSM
# 4                       0            ISO_IR 100         NaN    DDSM
#
#                                     StudyInstanceUID  StudyTime
# 0  1.3.6.1.4.1.9590.100.1.2.271867287611061855725...   214951.0
# 1  1.3.6.1.4.1.9590.100.1.2.161516517311681906612...   193426.0
# 2  1.3.6.1.4.1.9590.100.1.2.291043622711253836701...   161814.0
# 3  1.3.6.1.4.1.9590.100.1.2.335006093711888937440...   180109.0
# 4  1.3.6.1.4.1.9590.100.1.2.335006093711888937440...        NaN
#
# [5 rows x 38 columns]

# %%
# check image types in dataset
df_dicom.SeriesDescription.unique()
# Out:
# array(['cropped images', 'full mammogram images', nan, 'ROI mask images'],
#       dtype=object)

# %%
# check image path in dataset
# cropped images
cropped_images = df_dicom[df_dicom.SeriesDescription=='cropped images'].image_path
print(cropped_images.iloc[0])
# Out:
# CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308726812851964007517874181459556304/1-172.jpg

# %%
#full mammogram images
full_images = df_dicom[df_dicom.SeriesDescription=='full mammogram images'].image_path
print(full_images.iloc[0])
# Out:
# CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg

# %%
# ROI images
mask_images = df_dicom[df_dicom.SeriesDescription=='ROI mask images'].image_path
print(mask_images.iloc[0])
# Out:
# CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.153339052913121382622526066491844156138/2-270.jpg

# %%
# Change path from above to local image directory
path_to_replace = 'CBIS-DDSM/jpeg'
# set correct image path for image types
replacement_path = ddsm_path+'/jpeg'

cropped_images = cropped_images.replace(path_to_replace, replacement_path, regex=True)
full_images = full_images.replace(path_to_replace, replacement_path, regex=True)
mask_images = mask_images.replace(path_to_replace, replacement_path, regex=True)

# view new paths
print('Cropped Images paths:')
print(cropped_images.iloc[0])
print('Full mammo Images paths:')
print(full_images.iloc[0])
print('ROI Mask Images paths:')
print(mask_images.iloc[0])
# Out:
# Cropped Images paths:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.129308726812851964007517874181459556304/1-172.jpg
# Full mammo Images paths:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg
# ROI Mask Images paths:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.153339052913121382622526066491844156138/2-270.jpg

# %%
# organize image paths
full_images_dict = dict()
cropped_images_dict = dict()
mask_images_dict = dict()

for dicom in full_images:
    key = dicom.split("/")[5]
    full_images_dict[key] = dicom
for dicom in cropped_images:
    key = dicom.split("/")[5]
    cropped_images_dict[key] = dicom
for dicom in mask_images:
    key = dicom.split("/")[5]
    mask_images_dict[key] = dicom

# view keys
next(iter((full_images_dict.items())))
# Out:
# ('1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849',
#  '/kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg')

# %%
# Load the mass dataset
mass_train = pd.read_csv(ddsm_path+'/csv/mass_case_description_train_set.csv')
mass_test = pd.read_csv(ddsm_path+'/csv/mass_case_description_test_set.csv')
# Merge train and test
mass_df = pd.concat([mass_train, mass_test])

mass_train.head(1)
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00001               3                 LEFT         CC               1
#
#   abnormality type                          mass shape mass margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION   SPICULATED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
#
#                                      image file path  \
# 0  Mass-Training_P_00001_LEFT_CC/1.3.6.1.4.1.9590...
#
#                              cropped image file path  \
# 0  Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...
#
#                                   ROI mask file path
# 0  Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...

# %%
def fix_image_path(dataset):
    for i, img in enumerate(dataset.values):
        img_name = img[11].split("/")[2]
        if img_name in full_images_dict:
            dataset.iloc[i, 11] = full_images_dict[img_name]

        img_name = img[12].split("/")[2]
        if img_name in cropped_images_dict:
            dataset.iloc[i, 12] = cropped_images_dict[img_name]

        img_name = img[13].split("/")[2]
        if img_name in mask_images_dict:
            dataset.iloc[i, 13] = mask_images_dict[img_name]

# Fix image paths
fix_image_path(mass_df)
print(mass_df.iloc[1]['image file path'])
print(mass_df.iloc[1]['cropped image file path'])
print(mass_df.iloc[1]['ROI mask file path'])
# Out:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.359308329312397897125630708681441180834/1-207.jpg
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.227955274711225756835838775062793186053/1-289.jpg
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.227955274711225756835838775062793186053/2-288.jpg

# %% [markdown]
# # Fix Data

# %%
mass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1696 entries, 0 to 377
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_id               1696 non-null   object
#  1   breast_density           1696 non-null   int64
#  2   left or right breast     1696 non-null   object
#  3   image view               1696 non-null   object
#  4   abnormality id           1696 non-null   int64
#  5   abnormality type         1696 non-null   object
#  6   mass shape               1692 non-null   object
#  7   mass margins             1636 non-null   object
#  8   assessment               1696 non-null   int64
#  9   pathology                1696 non-null   object
#  10  subtlety                 1696 non-null   int64
#  11  image file path          1696 non-null   object
#  12  cropped image file path  1696 non-null   object
#  13  ROI mask file path       1696 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 198.8+ KB

# %%
# Rename columns to remove spaces
mass_df = mass_df.rename(columns={'left or right breast': 'left_or_right_breast',
                                           'image view': 'image_view',
                                           'abnormality id': 'abnormality_id',
                                           'abnormality type': 'abnormality_type',
                                           'mass shape': 'mass_shape',
                                           'mass margins': 'mass_margins',
                                           'image file path': 'image_file_path',
                                           'cropped image file path': 'cropped_image_file_path',
                                           'ROI mask file path': 'ROI_mask_file_path'})

mass_df.head(1)
# Out:
#   patient_id  breast_density left_or_right_breast image_view  abnormality_id  \
# 0    P_00001               3                 LEFT         CC               1
#
#   abnormality_type                          mass_shape mass_margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION   SPICULATED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
#
#                                      image_file_path  \
# 0  /kaggle/input/cbis-ddsm-breast-cancer-image-da...
#
#                              cropped_image_file_path  \
# 0  /kaggle/input/cbis-ddsm-breast-cancer-image-da...
#
#                                   ROI_mask_file_path
# 0  /kaggle/input/cbis-ddsm-breast-cancer-image-da...

# %%
# Check for nulls
mass_df.isnull().sum()
# Out:
# patient_id                  0
# breast_density              0
# left_or_right_breast        0
# image_view                  0
# abnormality_id              0
# abnormality_type            0
# mass_shape                  4
# mass_margins               60
# assessment                  0
# pathology                   0
# subtlety                    0
# image_file_path             0
# cropped_image_file_path     0
# ROI_mask_file_path          0
# dtype: int64

# %%
# Back fill null values
mass_df['mass_shape'] = mass_df['mass_shape'].bfill()
mass_df['mass_margins'] = mass_df['mass_margins'].bfill()

# Recheck
mass_df.isnull().sum()
# Out:
# patient_id                 0
# breast_density             0
# left_or_right_breast       0
# image_view                 0
# abnormality_id             0
# abnormality_type           0
# mass_shape                 0
# mass_margins               0
# assessment                 0
# pathology                  0
# subtlety                   0
# image_file_path            0
# cropped_image_file_path    0
# ROI_mask_file_path         0
# dtype: int64

# %%
# Summarise Features
mass_df.describe()
# Out:
#        breast_density  abnormality_id   assessment     subtlety
# count     1696.000000     1696.000000  1696.000000  1696.000000
# mean         2.246462        1.110849     3.511203     3.925708
# std          0.874071        0.452564     1.398648     1.120114
# min          1.000000        1.000000     0.000000     0.000000
# 25%          2.000000        1.000000     3.000000     3.000000
# 50%          2.000000        1.000000     4.000000     4.000000
# 75%          3.000000        1.000000     4.000000     5.000000
# max          4.000000        6.000000     5.000000     5.000000

# %%
# Check unique values in pathology column
print(mass_df.pathology.value_counts())
# Out:
# pathology
# MALIGNANT                  784
# BENIGN                     771
# BENIGN_WITHOUT_CALLBACK    141
# Name: count, dtype: int64

# %%
# Remap
mapper = {'MALIGNANT': 'MALIGNANT', 'BENIGN': 'BENIGN', 'BENIGN_WITHOUT_CALLBACK': 'BENIGN'}
mass_df['pathology'] = mass_df['pathology'].map(mapper)
# Check only two classes remain
mass_df.pathology.unique()
# Out:
# array(['MALIGNANT', 'BENIGN'], dtype=object)

# %%
# Check dataset shape
print(f'Shape of mass_train: {mass_df.shape}')
# Out:
# Shape of mass_train: (1696, 14)

# %% [markdown]
# # Visualizations

# %%
# Pathology distribution
value = mass_df['pathology'].value_counts()
plt.figure(figsize=(6,6))

plt.pie(value, labels=value.index, autopct='%1.1f%%')
plt.title('Breast Cancer Pathology Distribution', fontsize=15)
plt.show()

# %%
def display_images_by_type(dataframe, num_images_to_show=5):
    image_info = [
        {'column': 'image_file_path', 'title': 'Full Mammogram'},
        {'column': 'ROI_mask_file_path', 'title': 'Mask'},
        {'column': 'cropped_image_file_path', 'title': 'Cropped Mammogram'},
    ]

    num_image_types = len(image_info)
    fig, axes = plt.subplots(num_image_types, num_images_to_show, figsize=(num_images_to_show * 3, num_image_types * 3))
    top_n_entries = dataframe.head(num_images_to_show)

    for type_idx, info in enumerate(image_info):
        column_name = info['column']
        column_title = info['title']
        if type_idx == 0:
            fig.suptitle(f'Visualizing {num_images_to_show} Entries by Image Type', fontsize=16, y=1.02)

        for img_idx, (index, row_data) in enumerate(top_n_entries.iterrows()):
            image_path = row_data[column_name]
            image = mpimg.imread(image_path)

            ax = axes[type_idx][img_idx]
            ax.imshow(image, cmap='gray')

            if img_idx == 0:
                ax.set_ylabel(column_title, rotation=90, size='large', ha='right')
                ax.yaxis.set_label_coords(-0.25, 0.5)

            ax.set_title(f"Pathology: {row_data['pathology']}", fontsize=8)
            ax.axis('off')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()


display_images_by_type(mass_df, num_images_to_show=5)

# %% [markdown]
# # Preprocessing of Images

# %%
df = mass_df[['cropped_image_file_path', 'pathology']].copy()
df = df.dropna()  # Drop rows with missing paths or labels

# Split into train and test/validation
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['pathology'], random_state=12)

# Split into test and validation sets (10% of data each)
train_df, valid_df = train_test_split(train_df, test_size=0.5, stratify=train_df['pathology'], random_state=12)

# %%
# Define image dimensions and batch size
IMAGE_DIMENSIONS = (299, 299)
TRAINING_BATCH_SIZE = 32

# Basic Augmentation Pipeline
augmentation = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    width_shift_range=0.03,
    height_shift_range=0.03,
    shear_range=0.03,
    zoom_range=0.03,
    fill_mode='reflect',
    horizontal_flip=True,
    vertical_flip=True,
)

# Data generator for training data with augmentation
augmented_train = augmentation.flow_from_dataframe(
    dataframe=train_df,
    x_col='cropped_image_file_path',
    y_col='pathology',
    target_size=IMAGE_DIMENSIONS,
    batch_size=TRAINING_BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=12
)

# Data generators for validation and test data without augmentation (only rescaling)
validation_test_preprocessing = ImageDataGenerator(rescale=1./255)

augmented_validation = validation_test_preprocessing.flow_from_dataframe(
    dataframe=valid_df,
    x_col='cropped_image_file_path',
    y_col='pathology',
    target_size=IMAGE_DIMENSIONS,
    batch_size=TRAINING_BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=12
)

augmented_test = validation_test_preprocessing.flow_from_dataframe(
    dataframe=test_df,
    x_col='cropped_image_file_path',
    y_col='pathology',
    target_size=IMAGE_DIMENSIONS,
    batch_size=TRAINING_BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=42
)
# Out:
# Found 678 validated image filenames belonging to 2 classes.
# Found 678 validated image filenames belonging to 2 classes.
# Found 340 validated image filenames belonging to 2 classes.

# %%
# Get images
images, labels = next(augmented_train)

# Convert labels to names from binary
class_indices = augmented_train.class_indices
classes = list(class_indices.keys())
label_names = [classes[np.argmax(label)] for label in labels]

# Display the images
plt.figure(figsize=(10, 10))
for i in range(min(images.shape[0], 10)): # display 10
    plt.subplot(5, 5, i + 1)
    plt.imshow(images[i])
    plt.title(label_names[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # CNN Architecture

# %%
def create_model(train_set):
    img_shape = (299, 299, 3)  # must be 3 channels for pretrained models
    class_count = len(train_set.class_indices)
    print("Class count:", class_count)
    print("Class indices:", train_set.class_indices)

    base_model = InceptionV3(include_top=False, input_shape=img_shape, weights="imagenet")

    # unfreeze deeper blocks only
    for layer in base_model.layers[:200]:  # inception deeper than other models
        layer.trainable = False
    for layer in base_model.layers[200:]:
        layer.trainable = True

    # Global feature pooling
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)

    # Multi-branch dense head
    branch1 = Dense(1024, activation="relu", kernel_regularizer=l2(1e-4))(x)
    branch1 = Dropout(0.5)(branch1)
    branch1 = BatchNormalization()(branch1)

    branch2 = Dense(512, activation="relu", kernel_regularizer=l2(1e-4))(x)
    branch2 = Dropout(0.4)(branch2)
    branch2 = BatchNormalization()(branch2)

    branch3 = Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(x)
    branch3 = Dropout(0.3)(branch3)
    branch3 = BatchNormalization()(branch3)

    # Concatenate multiple feature projections
    x = Concatenate()([branch1, branch2, branch3])

    # Final bottleneck layer before output
    x = Dense(128, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.3)(x)
    x = BatchNormalization()(x)

    # Output for binary classification
    output = Dense(class_count, activation="sigmoid", name="output_sigmoid")(x)

    # Final model
    model = Model(inputs=base_model.input, outputs=output)

    # Optimizer with a very low LR (InceptionV3 is sensitive to fine-tuning)
    optimizer = Adam(learning_rate=3e-5)

    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc"),
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    model.summary()
    return model

model = create_model(augmented_train)
# Out:
# Class count: 2
# Class indices: {'BENIGN': 0, 'MALIGNANT': 1}
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_188 (Conv2D) │ (None, 149, 149,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 149, 149,  │         96 │ conv2d_188[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_188      │ (None, 149, 149,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_189 (Conv2D) │ (None, 147, 147,  │      9,216 │ activation_188[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 147, 147,  │         96 │ conv2d_189[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_189      │ (None, 147, 147,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_190 (Conv2D) │ (None, 147, 147,  │     18,432 │ activation_189[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 147, 147,  │        192 │ conv2d_190[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_190      │ (None, 147, 147,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 73, 73,    │          0 │ activation_190[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_191 (Conv2D) │ (None, 73, 73,    │      5,120 │ max_pooling2d_8[… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 73, 73,    │        240 │ conv2d_191[0][0]  │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_191      │ (None, 73, 73,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_192 (Conv2D) │ (None, 71, 71,    │    138,240 │ activation_191[0… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 71, 71,    │        576 │ conv2d_192[0][0]  │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_192      │ (None, 71, 71,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 35, 35,    │          0 │ activation_192[0… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, 35, 35,    │     12,288 │ max_pooling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_196[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_196      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_194 (Conv2D) │ (None, 35, 35,    │      9,216 │ max_pooling2d_9[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, 35, 35,    │     55,296 │ activation_196[0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_194[0][0]  │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_197[0][0]  │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_194      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_197      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 35, 35,    │          0 │ max_pooling2d_9[… │
# │ (AveragePooling2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_193 (Conv2D) │ (None, 35, 35,    │     12,288 │ max_pooling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_195 (Conv2D) │ (None, 35, 35,    │     76,800 │ activation_194[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_198 (Conv2D) │ (None, 35, 35,    │     82,944 │ activation_197[0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_199 (Conv2D) │ (None, 35, 35,    │      6,144 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_193[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_195[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_198[0][0]  │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │         96 │ conv2d_199[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_193      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_195      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_198      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_199      │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mix
0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_281      │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed10             │ (None, 8, 8,      │          0 │ activation_273[0… │
# │ (Concatenate)       │ 2048)             │            │ mixed9_1[0][0],   │
# │                     │                   │            │ concatenate_5[0]… │
# │                     │                   │            │ activation_281[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ mixed10[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2048)      │      8,192 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1024)      │  2,098,176 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 512)       │  1,049,088 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │    524,544 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1024)      │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 512)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256)       │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dropout_6[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dropout_7[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dropout_8[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 1792)      │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │    229,504 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128)       │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dropout_9[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_sigmoid      │ (None, 2)         │        258 │ batch_normalizat… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 25,720,226 (98.11 MB)
#  Trainable params: 18,713,794 (71.39 MB)
#  Non-trainable params: 7,006,432 (26.73 MB)

# %%
# Define callbacks
early_stop = EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=10,
    restore_best_weights=True # rollback to best model
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=5,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_inception_cbis.keras",  # save best model
    monitor="val_auc",
    mode="max",
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, checkpoint]

# %%
vk.layered_view(
    model
)
# Out:
# <PIL.Image.Image image mode=RGBA size=13496x1595>

# %%
def train_and_evaluate_model(model, train_generator, validation_generator, test_generator, num_epochs=60):
    # Model Training
    training_history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=num_epochs,
        callbacks=callbacks,
    )

    # Evaluate Model on Test Set
    test_predictions_probabilities = model.predict(test_generator)
    predicted_class_labels = np.argmax(test_predictions_probabilities, axis=1)
    true_class_labels = test_generator.classes

    # Calculate precision, recall, and F1 score.
    precision_score, recall_score, f1_score, _ = precision_recall_fscore_support(
        true_class_labels, predicted_class_labels, average='weighted', zero_division=0
    )

    # Calculate accuracy and auc
    loss, accuracy, auc, precision, recall = model.evaluate(test_generator, verbose=0)

    # Create metrics dict
    metrics = {
        'test_accuracy': accuracy,
        'test_loss': loss,
        'test_precision': precision,
        'test_recall': recall,
        'test_f1_score': f1_score,
        'test_auc': auc,
    }


    return training_history, metrics

history, metrics = train_and_evaluate_model(model, augmented_train, augmented_validation, augmented_test)
# Out:
# Epoch 1/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5085 - auc: 0.5394 - loss: 1.1016 - precision: 0.5259 - recall: 0.5293
# Epoch 1: val_auc improved from -inf to 0.52800, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 99s 3s/step - accuracy: 0.5092 - auc: 0.5395 - loss: 1.1017 - precision: 0.5262 - recall: 0.5300 - val_accuracy: 0.4749 - val_auc: 0.5280 - val_loss: 0.9866 - val_precision: 0.4971 - val_recall: 0.5118 - learning_rate: 3.0000e-05
# Epoch 2/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.6064 - auc: 0.5992 - loss: 1.0738 - precision: 0.5845 - recall: 0.6019
# Epoch 2: val_auc improved from 0.52800 to 0.62723, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.6055 - auc: 0.5990 - loss: 1.0739 - precision: 0.5839 - recall: 0.6009 - val_accuracy: 0.5959 - val_auc: 0.6272 - val_loss: 0.9568 - val_precision: 0.5959 - val_recall: 0.5546 - learning_rate: 3.0000e-05
# Epoch 3/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s
60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.8282 - auc: 0.8888 - loss: 0.7072 - precision: 0.8112 - recall: 0.8059
# Epoch 17: val_auc improved from 0.77267 to 0.77440, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8276 - auc: 0.8883 - loss: 0.7083 - precision: 0.8104 - recall: 0.8055 - val_accuracy: 0.6947 - val_auc: 0.7744 - val_loss: 0.8899 - val_precision: 0.6922 - val_recall: 0.7198 - learning_rate: 9.0000e-06
# Epoch 18/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.8604 - auc: 0.9116 - loss: 0.6653 - precision: 0.8414 - recall: 0.8348
# Epoch 18: val_auc did not improve from 0.77440
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 34s 872ms/step - accuracy: 0.8598 - auc: 0.9114 - loss: 0.6656 - precision: 0.8412 - recall: 0.8344 - val_accuracy: 0.6991 - val_auc: 0.7731 - val_loss: 0.8979 - val_precision: 0.6907 - val_recall: 0.7212 - learning_rate: 9.0000e-06
# Epoch 19/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.8071 - auc: 0.8764 - loss: 0.7376 - precision: 0.7969 - recall: 0.8087
# Epoch 19: val_auc did not improve from 0.77440
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 933ms/step - accuracy: 0.8073 - auc: 0.8763 - loss: 0.7376 - precision: 0.7970 - recall: 0.8088 - val_accuracy: 0.7050 - val_auc: 0.7727 - val_loss: 0.9044 - val_precision: 0.6910 - val_recall: 0.7124 - learning_rate: 9.0000e-06
# Epoch 20/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.8204 - auc: 0.8909 - loss: 0.7057 - precision: 0.8281 - recall: 0.7890
# Epoch 20: val_auc improved from 0.77440 to 0.77453, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.8206 - auc: 0.8910 - loss: 0.7054 - precision: 0.8278 - recall: 0.7891 - val_accuracy: 0.6976 - val_auc: 0.7745 - val_loss: 0.9055 - val_precision: 0.6900 - val_recall: 0.7124 - learning_rate: 9.0000e-06
# Epoch 21/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.8421 - auc: 0.9014 - loss: 0.6784 - precision: 0.8104 - recall: 0.8039
# Epoch 21: val_auc improved from 0.77453 to 0.77621, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8432 - auc: 0.9021 - loss: 0.6772 - precision: 0.8116 - recall: 0.8048 - val_accuracy: 0.6932 - val_auc: 0.7762 - val_loss: 0.9065 - val_precision: 0.6928 - val_recall: 0.7050 - learning_rate: 9.0000e-06
# Epoch 22/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.8269 - auc: 0.8864 - loss: 0.7114 - precision: 0.8008 - recall: 0.7862
# Epoch 22: val_auc did not improve from 0.77621
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 907ms/step - accuracy: 0.8273 - auc: 0.8867 - loss: 0.7107 - precision: 0.8016 - recall: 0.7864 - val_accuracy: 0.6947 - val_auc: 0.7762 - val_loss: 0.9094 - val_precision: 0.6903 - val_recall: 0.7035 - learning_rate: 2.7000e-06
# Epoch 23/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - accuracy: 0.8474 - auc: 0.9126 - loss: 0.6627 - precision: 0.8278 - recall: 0.8414
# Epoch 23: val_auc did not improve from 0.77621
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 877ms/step - accuracy: 0.8473 - auc: 0.9125 - loss: 0.6630 - precision: 0.8280 - recall: 0.8411 - val_accuracy: 0.6962 - val_auc: 0.7762 - val_loss: 0.9118 - val_precision: 0.6914 - val_recall: 0.7006 - learning_rate: 2.7000e-06
# Epoch 24/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.8835 - auc: 0.9304 - loss: 0.6283 - precision: 0.8632 - recall: 0.8583
# Epoch 24: val_auc improved from 0.77621 to 0.77622, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.8830 - auc: 0.9302 - loss: 0.6288 - precision: 0.8627 - recall: 0.8574 - val_accuracy: 0.6962 - val_auc: 0.7762 - val_loss: 0.9138 - val_precision: 0.6913 - val_recall: 0.7035 - learning_rate: 2.7000e-06
# Epoch 25/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.8189 - auc: 0.8954 - loss: 0.6972 - precision: 0.8058 - recall: 0.8238
# Epoch 25: val_auc did not improve from 0.77622
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 901ms/step - accuracy: 0.8201 - auc: 0.8957 - loss: 0.6965 - precision: 0.8067 - recall: 0.8242 - val_accuracy: 0.6976 - val_auc: 0.7762 - val_loss: 0.9140 - val_precision: 0.6919 - val_recall: 0.7021 - learning_rate: 2.7000e-06
# Epoch 26/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.8627 - auc: 0.9188 - loss: 0.6507 - precision: 0.8396 - recall: 0.8572
# Epoch 26: val_auc improved from 0.77622 to 0.77713, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.8619 - auc: 0.9183 - loss: 0.6517 - precision: 0.8389 - recall: 0.8562 - val_accuracy: 0.6991 - val_auc: 0.7771 - val_loss: 0.9149 - val_precision: 0.6942 - val_recall: 0.7065 - learning_rate: 2.7000e-06
# Epoch 27/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - accuracy: 0.8632 - auc: 0.9267 - loss: 0.6325 - precision: 0.8426 - recall: 0.8546
# Epoch 27: val_auc improved from 0.77713 to 0.77727, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.8632 - auc: 0.9264 - loss: 0.6332 - precision: 0.8426 - recall: 0.8538 - val_accuracy: 0.7050 - val_auc: 0.7773 - val_loss: 0.9163 - val_precision: 0.6952 - val_recall: 0.7065 - learning_rate: 1.0000e-06
# Epoch 28/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 0.8521 - auc: 0.8974 - loss: 0.6960 - precision: 0.8275 - recall: 0.8208
# Epoch 28: val_auc improved from 0.77727 to 0.77730, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.8517 - auc: 0.8976 - loss: 0.6955 - precision: 0.8274 - recall: 0.8209 - val_accuracy: 0.7050 - val_auc: 0.7773 - val_loss: 0.9169 - val_precision: 0.6953 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 29/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8464 - auc: 0.9069 - loss: 0.6727 - precision: 0.8286 - recall: 0.8188
# Epoch 29: val_auc improved from 0.77730 to 0.77798, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.8468 - auc: 0.9069 - loss: 0.6728 - precision: 0.8288 - recall: 0.8186 - val_accuracy: 0.7050 - val_auc: 0.7780 - val_loss: 0.9167 - val_precision: 0.6953 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 30/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.8723 - auc: 0.9240 - loss: 0.6388 - precision: 0.8440 - recall: 0.8575
# Epoch 30: val_auc improved from 0.77798 to 0.77868, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.8720 - auc: 0.9238 - loss: 0.6392 - precision: 0.8436 - recall: 0.8564 - val_accuracy: 0.7035 - val_auc: 0.7787 - val_loss: 0.9156 - val_precision: 0.6948 - val_recall: 0.7050 - learning_rate: 1.0000e-06
# Epoch 31/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8612 - auc: 0.9318 - loss: 0.6225 - precision: 0.8479 - recall: 0.8446
# Epoch 31: val_auc improved from 0.77868 to 0.77872, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 22s 996ms/step - accuracy: 0.8608 - auc: 0.9316 - loss: 0.6231 - precision: 0.8477 - recall: 0.8442 - val_accuracy: 0.7065 - val_auc: 0.7787 - val_loss: 0.9161 - val_precision: 0.6959 - val_recall: 0.7021 - learning_rate: 1.0000e-06
# Epoch 32/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 0.8439 - auc: 0.8988 - loss: 0.6904 - precision: 0.8225 - recall: 0.8067
# Epoch 32: val_auc improved from 0.77872 to 0.77890, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.8444 - auc: 0.8989 - loss: 0.6902 - precision: 0.8229 - recall: 0.8071 - val_accuracy: 0.7065 - val_auc: 0.7789 - val_loss: 0.9167 - val_precision: 0.6964 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 33/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 0.8617 - auc: 0.9069 - loss: 0.6743 - precision: 0.8467 - recall: 0.8252
# Epoch 33: val_auc did not improve from 0.77890
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 938ms/step - accuracy: 0.8617 - auc: 0.9071 - loss: 0.6739 - precision: 0.8468 - recall: 0.8257 - val_accuracy: 0.7050 - val_auc: 0.7786 - val_loss: 0.9183 - val_precision: 0.6959 - val_recall: 0.7021 - learning_rate: 1.0000e-06
# Epoch 34/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 773ms/step - accuracy: 0.8619 - auc: 0.9216 - loss: 0.6468 - precision: 0.8467 - recall: 0.8102
# Epoch 34: val_auc did not improve from 0.77890
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 921ms/step - accuracy: 0.8621 - auc: 0.9216 - loss: 0.6469 - precision: 0.8466 - recall: 0.8114 - val_accuracy: 0.7050 - val_auc: 0.7787 - val_loss: 0.9181 - val_precision: 0.6969 - val_recall: 0.7021 - learning_rate: 1.0000e-06
# Epoch 35/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.8338 - auc: 0.9091 - loss: 0.6663 - precision: 0.8214 - recall: 0.8038
# Epoch 35: val_auc did not improve from 0.77890
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 897ms/step - accuracy: 0.8336 - auc: 0.9091 - loss: 0.6665 - precision: 0.8215 - recall: 0.8044 - val_accuracy: 0.7065 - val_auc: 0.7783 - val_loss: 0.9182 - val_precision: 0.6965 - val_recall: 0.7006 - learning_rate: 1.0000e-06
# Epoch 36/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - accuracy: 0.8276 - auc: 0.8911 - loss: 0.6997 - precision: 0.7920 - recall: 0.8026
# Epoch 36: val_auc did not improve from 0.77890
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 902ms/step - accuracy: 0.8283 - auc: 0.8921 - loss: 0.6978 - precision: 0.7932 - recall: 0.8036 - val_accuracy: 0.7035 - val_auc: 0.7785 - val_loss: 0.9185 - val_precision: 0.6960 - val_recall: 0.6991 - learning_rate: 1.0000e-06
# Epoch 37/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.8661 - auc: 0.9045 - loss: 0.6854 - precision: 0.8450 - recall: 0.8397
# Epoch 37: val_auc improved from 0.77890 to 0.77899, saving model to best_inception_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8664 - auc: 0.9051 - loss: 0.6841 - precision: 0.8450 - recall: 0.8399 - val_accuracy: 0.7035 - val_auc: 0.7790 - val_loss: 0.9189 - val_precision: 0.6979 - val_recall: 0.7021 - learning_rate: 1.0000e-06
# Epoch 38/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.8709 - auc: 0.9315 - loss: 0.6227 - precision: 0.8487 - recall: 0.8494
# Epoch 38: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 892ms/step - accuracy: 0.8703 - auc: 0.9308 - loss: 0.6242 - precision: 0.8481 - recall: 0.8485 - val_accuracy: 0.7065 - val_auc: 0.7787 - val_loss: 0.9197 - val_precision: 0.6974 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 39/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - accuracy: 0.8674 - auc: 0.9203 - loss: 0.6488 - precision: 0.8610 - recall: 0.8552
# Epoch 39: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 884ms/step - accuracy: 0.8674 - auc: 0.9202 - loss: 0.6489 - precision: 0.8604 - recall: 0.8547 - val_accuracy: 0.7035 - val_auc: 0.7781 - val_loss: 0.9206 - val_precision: 0.6974 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 40/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.8378 - auc: 0.9096 - loss: 0.6691 - precision: 0.8327 - recall: 0.8296
# Epoch 40: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 921ms/step - accuracy: 0.8387 - auc: 0.9098 - loss: 0.6688 - precision: 0.8331 - recall: 0.8299 - val_accuracy: 0.7065 - val_auc: 0.7781 - val_loss: 0.9213 - val_precision: 0.6988 - val_recall: 0.7050 - learning_rate: 1.0000e-06
# Epoch 41/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.8327 - auc: 0.8961 - loss: 0.6954 - precision: 0.8276 - recall: 0.8111
# Epoch 41: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 871ms/step - accuracy: 0.8329 - auc: 0.8967 - loss: 0.6942 - precision: 0.8279 - recall: 0.8117 - val_accuracy: 0.7094 - val_auc: 0.7780 - val_loss: 0.9215 - val_precision: 0.6968 - val_recall: 0.7050 - learning_rate: 1.0000e-06
# Epoch 42/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.8371 - auc: 0.9003 - loss: 0.6910 - precision: 0.8237 - recall: 0.8060
# Epoch 42: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 920ms/step - accuracy: 0.8376 - auc: 0.9007 - loss: 0.6903 - precision: 0.8243 - recall: 0.8073 - val_accuracy: 0.7080 - val_auc: 0.7774 - val_loss: 0.9221 - val_precision: 0.6964 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 43/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.8539 - auc: 0.9158 - loss: 0.6560 - precision: 0.8251 - recall: 0.8372
# Epoch 43: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 905ms/step - accuracy: 0.8542 - auc: 0.9159 - loss: 0.6557 - precision: 0.8254 - recall: 0.8372 - val_accuracy: 0.7050 - val_auc: 0.7777 - val_loss: 0.9217 - val_precision: 0.6955 - val_recall: 0.7006 - learning_rate: 1.0000e-06
# Epoch 44/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.8600 - auc: 0.9196 - loss: 0.6464 - precision: 0.8374 - recall: 0.8226
# Epoch 44: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 887ms/step - accuracy: 0.8598 - auc: 0.9194 - loss: 0.6467 - precision: 0.8372 - recall: 0.8231 - val_accuracy: 0.7080 - val_auc: 0.7775 - val_loss: 0.9225 - val_precision: 0.7004 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 45/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 0.8218 - auc: 0.8998 - loss: 0.6877 - precision: 0.8331 - recall: 0.8274
# Epoch 45: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 929ms/step - accuracy: 0.8225 - auc: 0.9000 - loss: 0.6873 - precision: 0.8334 - recall: 0.8275 - val_accuracy: 0.7080 - val_auc: 0.7772 - val_loss: 0.9232 - val_precision: 0.6994 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 46/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.8702 - auc: 0.9172 - loss: 0.6522 - precision: 0.8344 - recall: 0.8576
# Epoch 46: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 885ms/step - accuracy: 0.8704 - auc: 0.9174 - loss: 0.6520 - precision: 0.8344 - recall: 0.8575 - val_accuracy: 0.7035 - val_auc: 0.7774 - val_loss: 0.9239 - val_precision: 0.7004 - val_recall: 0.7035 - learning_rate: 1.0000e-06
# Epoch 47/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.8687 - auc: 0.9303 - loss: 0.6257 - precision: 0.8383 - recall: 0.8760
# Epoch 47: val_auc did not improve from 0.77899
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 888ms/step - accuracy: 0.8685 - auc: 0.9302 - loss: 0.6259 - precision: 0.8387 - recall: 0.8751 - val_accuracy: 0.7035 - val_auc: 0.7772 - val_loss: 0.9249 - val_precision: 0.6996 - val_recall: 0.7006 - learning_rate: 1.0000e-06
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 781ms/step

# %% [markdown]
# # Evaluation

# %%
print(metrics)
# Out:
# {'test_accuracy': 0.7323529124259949, 'test_loss': 0.892924964427948, 'test_precision': 0.729106605052948, 'test_recall': 0.7441176176071167, 'test_f1_score': 0.7296882689152836, 'test_auc': 0.7992387413978577}

# %%
def confusion_matrix_plot(test, y_predict):
  y_pred = np.argmax(y_predict, axis=1)

  # get class indices and labels
  class_indices = test.class_indices
  classes = list(class_indices.keys())

  # compute confusion matrix
  cm = confusion_matrix(test.classes, y_pred)

  plt.figure(figsize=(10, 10))
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title('Confusion Matrix')
  plt.colorbar()

  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  threshold = cm.max() / 2.0
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(
          j, i, f"{cm[i, j]}",
          horizontalalignment='center',
          color='white' if cm[i, j] > threshold else 'black'
      )

  plt.tight_layout()
  plt.ylabel('True Label')
  plt.xlabel('Predicted Label')
  plt.show()

y_prediction = model.predict(augmented_test)
confusion_matrix_plot(augmented_test, y_prediction)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step

# %%
# Get the true labels and predicted probabilities for the positive class (MALIGNANT)
y_true = augmented_test.classes
y_pred_prob = y_prediction[:, 1]  # Get probabilities for the 'MALIGNANT' class

# Calculate the AUC
auc_score = auc(roc_curve(y_true, y_pred_prob)[0], roc_curve(y_true, y_pred_prob)[1])
print(f'AUC: {auc_score:.4f}')

# Plot the ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC: 0.7981

# %% [markdown]
# # Classification Report

# %%
# Visualize model history
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('training / validation accuracies')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('ReLU training / validation loss values')
plt.ylabel('Loss value')
plt.xlabel('Epoch')
plt.show()
