# %%
# Standard Library Imports
import os
import itertools
import warnings
warnings.filterwarnings("ignore")

# Data Handling and Numerical Operations
import numpy as np
import pandas as pd
import kagglehub as kh

# Plotting Libraries
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
# !pip install visualkeras
import visualkeras as vk

# Model Building and Preprocessing
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Flatten, MaxPooling2D, Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import get_file
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Model Evaluation and Metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, classification_report, roc_curve, auc, confusion_matrix


ddsm_path = kh.dataset_download("awsaf49/cbis-ddsm-breast-cancer-image-dataset")
print(ddsm_path)
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (11.3.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (2.0.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (1.3.19)
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset

# %% [markdown]
# # Data Preperation

# %%
df_meta = pd.read_csv(ddsm_path+'/csv/meta.csv')
df_meta.head()
# Out:
#                                    SeriesInstanceUID  \
# 0  1.3.6.1.4.1.9590.100.1.2.117041576511324414842...
# 1  1.3.6.1.4.1.9590.100.1.2.438738396107617880132...
# 2  1.3.6.1.4.1.9590.100.1.2.767416741131676463382...
# 3  1.3.6.1.4.1.9590.100.1.2.296931352612305599800...
# 4  1.3.6.1.4.1.9590.100.1.2.436657670120353100077...
#
#                                     StudyInstanceUID Modality  \
# 0  1.3.6.1.4.1.9590.100.1.2.229361142710768138411...       MG
# 1  1.3.6.1.4.1.9590.100.1.2.195593486612988388325...       MG
# 2  1.3.6.1.4.1.9590.100.1.2.257901172612530623323...       MG
# 3  1.3.6.1.4.1.9590.100.1.2.109468616710242115222...       MG
# 4  1.3.6.1.4.1.9590.100.1.2.380627129513562450304...       MG
#
#   SeriesDescription BodyPartExamined  SeriesNumber Collection  Visibility  \
# 0   ROI mask images           BREAST             1  CBIS-DDSM           1
# 1   ROI mask images           BREAST             1  CBIS-DDSM           1
# 2   ROI mask images           BREAST             1  CBIS-DDSM           1
# 3   ROI mask images           BREAST             1  CBIS-DDSM           1
# 4   ROI mask images           BREAST             1  CBIS-DDSM           1
#
#    ImageCount
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2

# %%
# load dicom info file
df_dicom = pd.read_csv(ddsm_path+'/csv/dicom_info.csv')
df_dicom.head()
# Out:
#                                            file_path  \
# 0  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
# 1  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24838...
# 2  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.26721...
# 3  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 4  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
#
#                                           image_path  AccessionNumber  \
# 0  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
# 1  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...              NaN
# 2  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.267213...              NaN
# 3  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
# 4  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
#
#    BitsAllocated  BitsStored BodyPartExamined  Columns  ContentDate  \
# 0             16          16           BREAST      351     20160426
# 1             16          16           BREAST     3526     20160426
# 2             16          16           BREAST     1546     20160503
# 3             16          16           BREAST       97     20160503
# 4              8           8      Left Breast     3104     20160503
#
#    ContentTime ConversionType  ...  \
# 0   131732.685            WSD  ...
# 1   143829.101            WSD  ...
# 2   111956.298            WSD  ...
# 3   115347.770            WSD  ...
# 4   115347.770            WSD  ...
#
#    SecondaryCaptureDeviceManufacturerModelName      SeriesDescription  \
# 0                                       MATLAB         cropped images
# 1                                       MATLAB  full mammogram images
# 2                                       MATLAB  full mammogram images
# 3                                       MATLAB         cropped images
# 4                                       MATLAB                    NaN
#
#                                    SeriesInstanceUID SeriesNumber  \
# 0  1.3.6.1.4.1.9590.100.1.2.129308726812851964007...            1
# 1  1.3.6.1.4.1.9590.100.1.2.248386742010678582309...            1
# 2  1.3.6.1.4.1.9590.100.1.2.267213171011171858918...            1
# 3  1.3.6.1.4.1.9590.100.1.2.381187369611524586537...            1
# 4  1.3.6.1.4.1.9590.100.1.2.381187369611524586537...            1
#
#   SmallestImagePixelValue  SpecificCharacterSet   StudyDate StudyID  \
# 0                   23078            ISO_IR 100  20160720.0    DDSM
# 1                       0            ISO_IR 100  20160720.0    DDSM
# 2                       0            ISO_IR 100  20160807.0    DDSM
# 3                   32298            ISO_IR 100  20170829.0    DDSM
# 4                       0            ISO_IR 100         NaN    DDSM
#
#                                     StudyInstanceUID  StudyTime
# 0  1.3.6.1.4.1.9590.100.1.2.271867287611061855725...   214951.0
# 1  1.3.6.1.4.1.9590.100.1.2.161516517311681906612...   193426.0
# 2  1.3.6.1.4.1.9590.100.1.2.291043622711253836701...   161814.0
# 3  1.3.6.1.4.1.9590.100.1.2.335006093711888937440...   180109.0
# 4  1.3.6.1.4.1.9590.100.1.2.335006093711888937440...        NaN
#
# [5 rows x 38 columns]

# %%
# check image types in dataset
df_dicom.SeriesDescription.unique()
# Out:
# array(['cropped images', 'full mammogram images', nan, 'ROI mask images'],
#       dtype=object)

# %%
# check image path in dataset
# cropped images
cropped_images = df_dicom[df_dicom.SeriesDescription=='cropped images'].image_path
print(cropped_images.iloc[0])
# Out:
# CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308726812851964007517874181459556304/1-172.jpg

# %%
#full mammogram images
full_images = df_dicom[df_dicom.SeriesDescription=='full mammogram images'].image_path
print(full_images.iloc[0])
# Out:
# CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg

# %%
# ROI images
mask_images = df_dicom[df_dicom.SeriesDescription=='ROI mask images'].image_path
print(mask_images.iloc[0])
# Out:
# CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.153339052913121382622526066491844156138/2-270.jpg

# %%
# Change path from above to local image directory
path_to_replace = 'CBIS-DDSM/jpeg'
# set correct image path for image types
replacement_path = ddsm_path+'/jpeg'

cropped_images = cropped_images.replace(path_to_replace, replacement_path, regex=True)
full_images = full_images.replace(path_to_replace, replacement_path, regex=True)
mask_images = mask_images.replace(path_to_replace, replacement_path, regex=True)

# view new paths
print('Cropped Images paths:')
print(cropped_images.iloc[0])
print('Full mammo Images paths:')
print(full_images.iloc[0])
print('ROI Mask Images paths:')
print(mask_images.iloc[0])
# Out:
# Cropped Images paths:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.129308726812851964007517874181459556304/1-172.jpg
# Full mammo Images paths:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg
# ROI Mask Images paths:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.153339052913121382622526066491844156138/2-270.jpg

# %%
# organize image paths
full_images_dict = dict()
cropped_images_dict = dict()
mask_images_dict = dict()

for dicom in full_images:
    key = dicom.split("/")[5]
    full_images_dict[key] = dicom
for dicom in cropped_images:
    key = dicom.split("/")[5]
    cropped_images_dict[key] = dicom
for dicom in mask_images:
    key = dicom.split("/")[5]
    mask_images_dict[key] = dicom

# view keys
next(iter((full_images_dict.items())))
# Out:
# ('1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849',
#  '/kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg')

# %%
# Load the mass dataset
mass_train = pd.read_csv(ddsm_path+'/csv/mass_case_description_train_set.csv')
mass_test = pd.read_csv(ddsm_path+'/csv/mass_case_description_test_set.csv')
# Merge train and test
mass_df = pd.concat([mass_train, mass_test])

mass_train.head(1)
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00001               3                 LEFT         CC               1
#
#   abnormality type                          mass shape mass margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION   SPICULATED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
#
#                                      image file path  \
# 0  Mass-Training_P_00001_LEFT_CC/1.3.6.1.4.1.9590...
#
#                              cropped image file path  \
# 0  Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...
#
#                                   ROI mask file path
# 0  Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...

# %%
def fix_image_path(dataset):
    for i, img in enumerate(dataset.values):
        img_name = img[11].split("/")[2]
        if img_name in full_images_dict:
            dataset.iloc[i, 11] = full_images_dict[img_name]

        img_name = img[12].split("/")[2]
        if img_name in cropped_images_dict:
            dataset.iloc[i, 12] = cropped_images_dict[img_name]

        img_name = img[13].split("/")[2]
        if img_name in mask_images_dict:
            dataset.iloc[i, 13] = mask_images_dict[img_name]

# Fix image paths
fix_image_path(mass_df)
print(mass_df.iloc[1]['image file path'])
print(mass_df.iloc[1]['cropped image file path'])
print(mass_df.iloc[1]['ROI mask file path'])
# Out:
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.359308329312397897125630708681441180834/1-207.jpg
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.227955274711225756835838775062793186053/1-289.jpg
# /kaggle/input/cbis-ddsm-breast-cancer-image-dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.227955274711225756835838775062793186053/2-288.jpg

# %% [markdown]
# # Fix Data

# %%
mass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1696 entries, 0 to 377
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_id               1696 non-null   object
#  1   breast_density           1696 non-null   int64
#  2   left or right breast     1696 non-null   object
#  3   image view               1696 non-null   object
#  4   abnormality id           1696 non-null   int64
#  5   abnormality type         1696 non-null   object
#  6   mass shape               1692 non-null   object
#  7   mass margins             1636 non-null   object
#  8   assessment               1696 non-null   int64
#  9   pathology                1696 non-null   object
#  10  subtlety                 1696 non-null   int64
#  11  image file path          1696 non-null   object
#  12  cropped image file path  1696 non-null   object
#  13  ROI mask file path       1696 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 198.8+ KB

# %%
# Rename columns to remove spaces
mass_df = mass_df.rename(columns={'left or right breast': 'left_or_right_breast',
                                           'image view': 'image_view',
                                           'abnormality id': 'abnormality_id',
                                           'abnormality type': 'abnormality_type',
                                           'mass shape': 'mass_shape',
                                           'mass margins': 'mass_margins',
                                           'image file path': 'image_file_path',
                                           'cropped image file path': 'cropped_image_file_path',
                                           'ROI mask file path': 'ROI_mask_file_path'})

mass_df.head(1)
# Out:
#   patient_id  breast_density left_or_right_breast image_view  abnormality_id  \
# 0    P_00001               3                 LEFT         CC               1
#
#   abnormality_type                          mass_shape mass_margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION   SPICULATED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
#
#                                      image_file_path  \
# 0  /kaggle/input/cbis-ddsm-breast-cancer-image-da...
#
#                              cropped_image_file_path  \
# 0  /kaggle/input/cbis-ddsm-breast-cancer-image-da...
#
#                                   ROI_mask_file_path
# 0  /kaggle/input/cbis-ddsm-breast-cancer-image-da...

# %%
# Check for nulls
mass_df.isnull().sum()
# Out:
# patient_id                  0
# breast_density              0
# left_or_right_breast        0
# image_view                  0
# abnormality_id              0
# abnormality_type            0
# mass_shape                  4
# mass_margins               60
# assessment                  0
# pathology                   0
# subtlety                    0
# image_file_path             0
# cropped_image_file_path     0
# ROI_mask_file_path          0
# dtype: int64

# %%
# Back fill null values
mass_df['mass_shape'] = mass_df['mass_shape'].bfill()
mass_df['mass_margins'] = mass_df['mass_margins'].bfill()

# Recheck
mass_df.isnull().sum()
# Out:
# patient_id                 0
# breast_density             0
# left_or_right_breast       0
# image_view                 0
# abnormality_id             0
# abnormality_type           0
# mass_shape                 0
# mass_margins               0
# assessment                 0
# pathology                  0
# subtlety                   0
# image_file_path            0
# cropped_image_file_path    0
# ROI_mask_file_path         0
# dtype: int64

# %%
# Summarise Features
mass_df.describe()
# Out:
#        breast_density  abnormality_id   assessment     subtlety
# count     1696.000000     1696.000000  1696.000000  1696.000000
# mean         2.246462        1.110849     3.511203     3.925708
# std          0.874071        0.452564     1.398648     1.120114
# min          1.000000        1.000000     0.000000     0.000000
# 25%          2.000000        1.000000     3.000000     3.000000
# 50%          2.000000        1.000000     4.000000     4.000000
# 75%          3.000000        1.000000     4.000000     5.000000
# max          4.000000        6.000000     5.000000     5.000000

# %%
# Check unique values in pathology column
print(mass_df.pathology.value_counts())
# Out:
# pathology
# MALIGNANT                  784
# BENIGN                     771
# BENIGN_WITHOUT_CALLBACK    141
# Name: count, dtype: int64

# %%
# Remap
mapper = {'MALIGNANT': 'MALIGNANT', 'BENIGN': 'BENIGN', 'BENIGN_WITHOUT_CALLBACK': 'BENIGN'}
mass_df['pathology'] = mass_df['pathology'].map(mapper)
# Check only two classes remain
mass_df.pathology.unique()
# Out:
# array(['MALIGNANT', 'BENIGN'], dtype=object)

# %%
# Check dataset shape
print(f'Shape of mass_train: {mass_df.shape}')
# Out:
# Shape of mass_train: (1696, 14)

# %% [markdown]
# # Visualizations

# %%
# Pathology distribution
value = mass_df['pathology'].value_counts()
plt.figure(figsize=(6,6))

plt.pie(value, labels=value.index, autopct='%1.1f%%')
plt.title('Breast Cancer Pathology Distribution', fontsize=15)
plt.show()

# %%
def display_images_by_type(dataframe, num_images_to_show=5):
    image_info = [
        {'column': 'image_file_path', 'title': 'Full Mammogram'},
        {'column': 'ROI_mask_file_path', 'title': 'Mask'},
        {'column': 'cropped_image_file_path', 'title': 'Cropped Mammogram'},
    ]

    num_image_types = len(image_info)
    fig, axes = plt.subplots(num_image_types, num_images_to_show, figsize=(num_images_to_show * 3, num_image_types * 3))
    top_n_entries = dataframe.head(num_images_to_show)

    for type_idx, info in enumerate(image_info):
        column_name = info['column']
        column_title = info['title']
        if type_idx == 0:
            fig.suptitle(f'Visualizing {num_images_to_show} Entries by Image Type', fontsize=16, y=1.02)

        for img_idx, (index, row_data) in enumerate(top_n_entries.iterrows()):
            image_path = row_data[column_name]
            image = mpimg.imread(image_path)

            ax = axes[type_idx][img_idx]
            ax.imshow(image, cmap='gray')

            if img_idx == 0:
                ax.set_ylabel(column_title, rotation=90, size='large', ha='right')
                ax.yaxis.set_label_coords(-0.25, 0.5)

            ax.set_title(f"Pathology: {row_data['pathology']}", fontsize=8)
            ax.axis('off')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()


display_images_by_type(mass_df, num_images_to_show=5)

# %% [markdown]
# # Preprocessing of Images

# %%
df = mass_df[['cropped_image_file_path', 'pathology']].copy()
df = df.dropna()  # Drop rows with missing paths or labels

# Split into train and test/validation
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['pathology'], random_state=12)

# Split into test and validation sets (10% of data each)
train_df, valid_df = train_test_split(train_df, test_size=0.5, stratify=train_df['pathology'], random_state=12)

# %%
# Define image dimensions and batch size
IMAGE_DIMENSIONS = (224, 224)
TRAINING_BATCH_SIZE = 32

# Basic Augmentation Pipeline
augmentation = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    width_shift_range=0.03,
    height_shift_range=0.03,
    shear_range=0.03,
    zoom_range=0.03,
    fill_mode='reflect',
    horizontal_flip=True,
    vertical_flip=True,
)

# Data generator for training data with augmentation
augmented_train = augmentation.flow_from_dataframe(
    dataframe=train_df,
    x_col='cropped_image_file_path',
    y_col='pathology',
    target_size=IMAGE_DIMENSIONS,
    batch_size=TRAINING_BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=12
)

# Data generators for validation and test data without augmentation (only rescaling)
validation_test_preprocessing = ImageDataGenerator(rescale=1./255)

augmented_validation = validation_test_preprocessing.flow_from_dataframe(
    dataframe=valid_df,
    x_col='cropped_image_file_path',
    y_col='pathology',
    target_size=IMAGE_DIMENSIONS,
    batch_size=TRAINING_BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=12
)

augmented_test = validation_test_preprocessing.flow_from_dataframe(
    dataframe=test_df,
    x_col='cropped_image_file_path',
    y_col='pathology',
    target_size=IMAGE_DIMENSIONS,
    batch_size=TRAINING_BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=42
)
# Out:
# Found 678 validated image filenames belonging to 2 classes.
# Found 678 validated image filenames belonging to 2 classes.
# Found 340 validated image filenames belonging to 2 classes.

# %%
# Get images
images, labels = next(augmented_train)

# Convert labels to names from binary
class_indices = augmented_train.class_indices
classes = list(class_indices.keys())
label_names = [classes[np.argmax(label)] for label in labels]

# Display the images
plt.figure(figsize=(10, 10))
for i in range(min(images.shape[0], 10)): # display 10
    plt.subplot(5, 5, i + 1)
    plt.imshow(images[i])
    plt.title(label_names[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # CNN Architecture

# %%
def create_model(train_set):
    img_shape = (int(224), int(224), int(3)) # has to be 3 channel for pretrained models
    class_count = len(train_set.class_indices)
    print("Class count:", class_count)
    print("Class indices:", train_set.class_indices)

    base_model = ResNet50V2(include_top=False, input_shape=img_shape, weights="imagenet")

    # Freeze early layers
    for layer in base_model.layers[:140]:
        layer.trainable = False
    for layer in base_model.layers[140:]:
        layer.trainable = True

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)

    # Dense head with strong regularization
    x = Dense(1024, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)

    x = Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.4)(x)
    x = BatchNormalization()(x)

    x = Dense(64, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.3)(x)
    x = BatchNormalization()(x)

    output = Dense(class_count, activation="sigmoid", name="output_sigmoid")(x)
    model = Model(inputs=base_model.input, outputs=output)

    optimizer = Adam(learning_rate=3e-5)
    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc"),
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
        ]
    )
    model.summary()
    return model

model = create_model(augmented_train)
# Out:
# Class count: 2
# Class indices: {'BENIGN': 0, 'MALIGNANT': 1}
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_2[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_conv[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 56, 56,    │        256 │ pool1_pool[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 56, 56,    │          0 │ conv2_block1_pre… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,096 │ conv2_block1_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_pad  │ (None, 58, 58,    │          0 │ conv2_block1_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block1_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_0_c… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 56, 56,    │      1,024 │ conv2_block1_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 56, 56,    │          0 │ conv2_block2_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,384 │ conv2_block2_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_pad  │ (None, 58, 58,    │          0 │ conv2_block2_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block2_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 56, 56,    │      1,024 │ conv2_block2_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 56, 56,    │          0 │ conv2_block3_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,384 │ conv2_block3_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_pad  │ (None, 58, 58,    │          0 │ conv2_block3_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 28, 28,    │     36,864 │ conv2_block3_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 28, 28,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 28, 28,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 28, 28,    │          0 │ conv2_block2_out… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 28, 28,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 28, 28,    │          0 │ max_pooling2d_6[… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 28, 28,    │      1,024 │ conv2_block3_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 28, 28,    │          0 │ conv3_block1_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,768 │ conv3_block1_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_pad  │ (None, 30, 30,    │          0 │ conv3_block1_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,456 │ conv3_block1_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv3_block1_pre… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_0_c… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 28, 28,    │      2,048 │ conv3_block1_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 28, 28,    │          0 │ conv3_block2_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,536 │ conv3_block2_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_pad  │ (None, 30, 30,    │          0 │ conv3_block2_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,456 │ conv3_block2_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 28, 28,    │      2,048 │ conv3_block2_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 28, 28,    │          0 │ conv3_block3_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,536 │ conv3_block3_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_pad  │ (None, 30, 30,    │          0 │ conv3_block3_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,456 │ conv3_block3_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 28, 28,    │      2,048 │ conv3_block3_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 28, 28,    │          0 │ conv3_block4_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,536 │ conv3_block4_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_pad  │ (None, 30, 30,    │          0 │ conv3_block4_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 14, 14,    │    147,456 │ conv3_block4_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 14, 14,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 14, 14,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 14, 14,    │          0 │ conv3_block3_out… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 14, 14,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 14, 14,    │          0 │ max_pooling2d_7[… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 14, 14,    │      2,048 │ conv3_block4_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 14, 14,    │          0 │ conv4_block1_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,072 │ conv4_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_pad  │ (None, 16, 16,    │          0 │ conv4_block1_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block1_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv4_block1_pre… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_0_c… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 14, 14,    │      4,096 │ conv4_block1_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 14, 14,    │          0 │ conv4_block2_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block2_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_pad  │ (None, 16, 16,    │          0 │ conv4_block2_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block2_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 14, 14,    │      4,096 │ conv4_block2_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 14, 14,    │          0 │ conv4_block3_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block3_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_pad  │ (None, 16, 16,    │          0 │ conv4_block3_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block3_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 14, 14,    │      4,096 │ conv4_block3_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 14, 14,    │          0 │ conv4_block4_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block4_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_pad  │ (None, 16, 16,    │          0 │ conv4_block4_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block4_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 14, 14,    │      4,096 │ conv4_block4_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 14, 14,    │          0 │ conv4_block5_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block5_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_pad  │ (None, 16, 16,    │          0 │ conv4_block5_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block5_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 14, 14,    │      4,096 │ conv4_block5_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 14, 14,    │          0 │ conv4_block6_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block6_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_pad  │ (None, 16, 16,    │          0 │ conv4_block6_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 7, 7, 256) │    589,824 │ conv4_block6_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 7, 7, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 7, 7, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 7, 7,      │          0 │ conv4_block5_out… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 7, 7,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 7, 7,      │          0 │ max_pooling2d_8[… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 7, 7,      │      4,096 │ conv4_block6_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 7, 7,      │          0 │ conv5_block1_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,288 │ conv5_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_pad  │ (None, 9, 9, 512) │          0 │ conv5_block1_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,296 │ conv5_block1_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv5_block1_pre… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_0_c… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 7, 7,      │      8,192 │ conv5_block1_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 7, 7,      │          0 │ conv5_block2_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,048,576 │ conv5_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_pad  │ (None, 9, 9, 512) │          0 │ conv5_block2_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,296 │ conv5_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 7, 7,      │      8,192 │ conv5_block2_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 7, 7,      │          0 │ conv5_block3_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,048,576 │ conv5_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_pad  │ (None, 9, 9, 512) │          0 │ conv5_block3_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,296 │ conv5_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_bn             │ (None, 7, 7,      │      8,192 │ conv5_block3_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_relu           │ (None, 7, 7,      │          0 │ post_bn[0][0]     │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ post_relu[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2048)      │      8,192 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1024)      │  2,098,176 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1024)      │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dropout_6[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │    262,400 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dropout_7[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │     16,448 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64)        │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dropout_8[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_sigmoid      │ (None, 2)         │        130 │ batch_normalizat… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 25,955,522 (99.01 MB)
#  Trainable params: 18,736,194 (71.47 MB)
#  Non-trainable params: 7,219,328 (27.54 MB)

# %%
# Define callbacks
early_stop = EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=10,
    restore_best_weights=True # rollback to best model
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=5,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_densenet_cbis.keras",  # save best model
    monitor="val_auc",
    mode="max",
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, checkpoint]

# %%
vk.layered_view(
    model
)
# Out:
# <PIL.Image.Image image mode=RGBA size=12932x1227>

# %%
def train_and_evaluate_model(model, train_generator, validation_generator, test_generator, num_epochs=60):
    # Model Training
    training_history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=num_epochs,
        callbacks=callbacks,
    )

    # Evaluate Model on Test Set
    test_predictions_probabilities = model.predict(test_generator)
    predicted_class_labels = np.argmax(test_predictions_probabilities, axis=1)
    true_class_labels = test_generator.classes

    # Calculate precision, recall, and F1 score.
    precision_score, recall_score, f1_score, _ = precision_recall_fscore_support(
        true_class_labels, predicted_class_labels, average='weighted', zero_division=0
    )

    # Calculate accuracy and auc
    loss, accuracy, auc, precision, recall = model.evaluate(test_generator, verbose=0)

    # Create metrics dict
    metrics = {
        'test_accuracy': accuracy,
        'test_loss': loss,
        'test_precision': precision,
        'test_recall': recall,
        'test_f1_score': f1_score,
        'test_auc': auc,
    }


    return training_history, metrics

history, metrics = train_and_evaluate_model(model, augmented_train, augmented_validation, augmented_test)
# Out:
# Epoch 1/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.5045 - auc: 0.5151 - loss: 1.0498 - precision: 0.5111 - recall: 0.5213
# Epoch 1: val_auc improved from -inf to 0.49401, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.5048 - auc: 0.5153 - loss: 1.0497 - precision: 0.5113 - recall: 0.5215 - val_accuracy: 0.5044 - val_auc: 0.4940 - val_loss: 0.8919 - val_precision: 0.5725 - val_recall: 0.1165 - learning_rate: 3.0000e-05
# Epoch 2/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.5404 - auc: 0.5434 - loss: 1.0229 - precision: 0.5360 - recall: 0.5175
# Epoch 2: val_auc improved from 0.49401 to 0.55620, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 734ms/step - accuracy: 0.5412 - auc: 0.5436 - loss: 1.0228 - precision: 0.5357 - recall: 0.5177 - val_accuracy: 0.5590 - val_auc: 0.5562 - val_loss: 0.8811 - val_precision: 0.5513 - val_recall: 0.1903 - learning_rate: 3.0000e-05
# Epoch 3/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.5225 - auc: 0.5248 - loss: 1.0209 - precision: 0.5033 - recall: 0.5104
# Epoch 3: val_auc improved from 0.55620 to 0.59038, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 630ms/step - accuracy: 0.5239 - auc: 0.5256 - loss: 1.0204 - precision: 0.5040 - recall: 0.5108 - val_accuracy: 0.5767 - val_auc: 0.5904 - val_loss: 0.8726 - val_precision: 0.5877 - val_recall: 0.3112 - learning_rate: 3.0000e-05
# Epoch 4/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.5843 - auc: 0.5482 - loss: 1.0090 - precision: 0.5505 - recall: 0.5414
# Epoch 4: val_auc improved from 0.59038 to 0.60742, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 637ms/step - accuracy: 0.5843 - auc: 0.5487 - loss: 1.0087 - precision: 0.5503 - recall: 0.5416 - val_accuracy: 0.5973 - val_auc: 0.6074 - val_loss: 0.8668 - val_precision: 0.6000 - val_recall: 0.3850 - learning_rate: 3.0000e-05
# Epoch 5/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.5609 - auc: 0.5684 - loss: 1.0052 - precision: 0.5592 - recall: 0.5485
# Epoch 5: val_auc improved from 0.60742 to 0.62952, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 629ms/step - accuracy: 0.5623 - auc: 0.5689 - loss: 1.0046 - precision: 0.5596 - recall: 0.5487 - val_accuracy: 0.6032 - val_auc: 0.6295 - val_loss: 0.8600 - val_precision: 0.6257 - val_recall: 0.4661 - learning_rate: 3.0000e-05
# Epoch 6/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.5891 - auc: 0.5881 - loss: 0.9663 - precision: 0.5561 - recall: 0.5648
# Epoch 6: val_auc improved from 0.62952 to 0.63962, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 655ms/step - accuracy: 0.5884 - auc: 0.5876 - loss: 0.9669 - precision: 0.5563 - recall: 0.5650 - val_accuracy: 0.6121 - val_auc: 0.6396 - val_loss: 0.8534 - val_precision: 0.6096 - val_recall: 0.4882 - learning_rate: 3.0000e-05
# Epoch 7/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.5641 - auc: 0.5708 - loss: 0.9865 - precision: 0.5530 - recall: 0.5569
# Epoch 7: val_auc improved from 0.63962 to 0.65922, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 636ms/step - accuracy: 0.5649 - auc: 0.5713 - loss: 0.9858 - precision: 0.5533 - recall: 0.5572 - val_accuracy: 0.6224 - val_auc: 0.6592 - val_loss: 0.8429 - val_precision: 0.6252 - val_recall: 0.5265 - learning_rate: 3.0000e-05
# Epoch 8/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5901 - auc: 0.5878 - loss: 0.9742 - precision: 0.5577 - recall: 0.5591
# Epoch 8: val_auc improved from 0.65922 to 0.66971, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 620ms/step - accuracy: 0.5909 - auc: 0.5881 - loss: 0.9742 - precision: 0.5581 - recall: 0.5592 - val_accuracy: 0.6416 - val_auc: 0.6697 - val_loss: 0.8363 - val_precision: 0.6329 - val_recall: 0.5442 - learning_rate: 3.0000e-05
# Epoch 9/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.5934 - auc: 0.5939 - loss: 0.9714 - precision: 0.5737 - recall: 0.5754
# Epoch 9: val_auc improved from 0.66971 to 0.67618, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 611ms/step - accuracy: 0.5937 - auc: 0.5941 - loss: 0.9711 - precision: 0.5735 - recall: 0.5748 - val_accuracy: 0.6504 - val_auc: 0.6762 - val_loss: 0.8329 - val_precision: 0.6413 - val_recall: 0.5590 - learning_rate: 3.0000e-05
# Epoch 10/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.5710 - auc: 0.5796 - loss: 0.9717 - precision: 0.5570 - recall: 0.5661
# Epoch 10: val_auc improved from 0.67618 to 0.69229, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 623ms/step - accuracy: 0.5715 - auc: 0.5799 - loss: 0.9715 - precision: 0.5572 - recall: 0.5658 - val_accuracy: 0.6593 - val_auc: 0.6923 - val_loss: 0.8243 - val_precision: 0.6495 - val_recall: 0.5767 - learning_rate: 3.0000e-05
# Epoch 11/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.6381 - auc: 0.6307 - loss: 0.9216 - precision: 0.5907 - recall: 0.5964
# Epoch 11: val_auc improved from 0.69229 to 0.70725, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 678ms/step - accuracy: 0.6379 - auc: 0.6303 - loss: 0.9221 - precision: 0.5903 - recall: 0.5962 - val_accuracy: 0.6814 - val_auc: 0.7072 - val_loss: 0.8157 - val_precision: 0.6597 - val_recall: 0.6091 - learning_rate: 3.0000e-05
# Epoch 12/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.6381 - auc: 0.6391 - loss: 0.9094 - precision: 0.5991 - recall: 0.5893
# Epoch 12: val_auc improved from 0.70725 to 0.71578, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 729ms/step - accuracy: 0.6389 - auc: 0.6394 - loss: 0.9094 - precision: 0.5995 - recall: 0.5897 - val_accuracy: 0.6740 - val_auc: 0.7158 - val_loss: 0.8101 - val_precision: 0.6715 - val_recall: 0.6121 - learning_rate: 3.0000e-05
# Epoch 13/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.6460 - auc: 0.6579 - loss: 0.8820 - precision: 0.6071 - recall: 0.6285
# Epoch 13: val_auc improved from 0.71578 to 0.72133, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 631ms/step - accuracy: 0.6451 - auc: 0.6573 - loss: 0.8830 - precision: 0.6070 - recall: 0.6280 - val_accuracy: 0.6858 - val_auc: 0.7213 - val_loss: 0.8054 - val_precision: 0.6766 - val_recall: 0.6357 - learning_rate: 3.0000e-05
# Epoch 14/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.6547 - auc: 0.6435 - loss: 0.9127 - precision: 0.6132 - recall: 0.6095
# Epoch 14: val_auc improved from 0.72133 to 0.72590, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 638ms/step - accuracy: 0.6544 - auc: 0.6436 - loss: 0.9127 - precision: 0.6133 - recall: 0.6095 - val_accuracy: 0.6991 - val_auc: 0.7259 - val_loss: 0.8021 - val_precision: 0.6840 - val_recall: 0.6416 - learning_rate: 3.0000e-05
# Epoch 15/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.5959 - auc: 0.6166 - loss: 0.9389 - precision: 0.5720 - recall: 0.5718
# Epoch 15: val_auc improved from 0.72590 to 0.72858, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 661ms/step - accuracy: 0.5968 - auc: 0.6170 - loss: 0.9386 - precision: 0.5724 - recall: 0.5725 - val_accuracy: 0.7021 - val_auc: 0.7286 - val_loss: 0.7997 - val_precision: 0.6901 - val_recall: 0.6504 - learning_rate: 3.0000e-05
# Epoch 16/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.6542 - auc: 0.6584 - loss: 0.8903 - precision: 0.6138 - recall: 0.6114
# Epoch 16: val_auc improved from 0.72858 to 0.73197, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 17s 779ms/step - accuracy: 0.6544 - auc: 0.6586 - loss: 0.8904 - precision: 0.6143 - recall: 0.6118 - val_accuracy: 0.6962 - val_auc: 0.7320 - val_loss: 0.7975 - val_precision: 0.6888 - val_recall: 0.6431 - learning_rate: 3.0000e-05
# Epoch 17/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.6559 - auc: 0.6551 - loss: 0.8953 - precision: 0.6079 - recall: 0.6135
# Epoch 17: val_auc improved from 0.73197 to 0.73591, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 624ms/step - accuracy: 0.6564 - auc: 0.6556 - loss: 0.8950 - precision: 0.6082 - recall: 0.6139 - val_accuracy: 0.7006 - val_auc: 0.7359 - val_loss: 0.7945 - val_precision: 0.6966 - val_recall: 0.6637 - learning_rate: 3.0000e-05
# Epoch 18/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.6652 - auc: 0.6717 - loss: 0.8759 - precision: 0.6264 - recall: 0.6416
# Epoch 18: val_auc improved from 0.73591 to 0.73602, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 637ms/step - accuracy: 0.6662 - auc: 0.6720 - loss: 0.8757 - precision: 0.6264 - recall: 0.6415 - val_accuracy: 0.6932 - val_auc: 0.7360 - val_loss: 0.7945 - val_precision: 0.6884 - val_recall: 0.6549 - learning_rate: 3.0000e-05
# Epoch 19/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.7048 - auc: 0.6946 - loss: 0.8529 - precision: 0.6352 - recall: 0.6365
# Epoch 19: val_auc improved from 0.73602 to 0.73756, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 656ms/step - accuracy: 0.7034 - auc: 0.6940 - loss: 0.8538 - precision: 0.6347 - recall: 0.6361 - val_accuracy: 0.6991 - val_auc: 0.7376 - val_loss: 0.7949 - val_precision: 0.6926 - val_recall: 0.6313 - learning_rate: 3.0000e-05
# Epoch 20/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6603 - auc: 0.6511 - loss: 0.9123 - precision: 0.6121 - recall: 0.6100
# Epoch 20: val_auc improved from 0.73756 to 0.74194, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 669ms/step - accuracy: 0.6612 - auc: 0.6525 - loss: 0.9106 - precision: 0.6134 - recall: 0.6109 - val_accuracy: 0.7065 - val_auc: 0.7419 - val_loss: 0.7923 - val_precision: 0.6990 - val_recall: 0.6475 - learning_rate: 3.0000e-05
# Epoch 21/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.7088 - auc: 0.7119 - loss: 0.8349 - precision: 0.6597 - recall: 0.6530
# Epoch 21: val_auc improved from 0.74194 to 0.74585, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - accuracy: 0.7077 - auc: 0.7111 - loss: 0.8360 - precision: 0.6589 - recall: 0.6525 - val_accuracy: 0.7094 - val_auc: 0.7459 - val_loss: 0.7896 - val_precision: 0.7003 - val_recall: 0.6549 - learning_rate: 3.0000e-05
# Epoch 22/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.6872 - auc: 0.6803 - loss: 0.8735 - precision: 0.6189 - recall: 0.6107
# Epoch 22: val_auc did not improve from 0.74585
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 581ms/step - accuracy: 0.6875 - auc: 0.6805 - loss: 0.8733 - precision: 0.6193 - recall: 0.6115 - val_accuracy: 0.7006 - val_auc: 0.7457 - val_loss: 0.7907 - val_precision: 0.6950 - val_recall: 0.6622 - learning_rate: 3.0000e-05
# Epoch 23/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.7194 - auc: 0.7132 - loss: 0.8347 - precision: 0.6581 - recall: 0.6642
# Epoch 23: val_auc improved from 0.74585 to 0.74980, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 668ms/step - accuracy: 0.7191 - auc: 0.7131 - loss: 0.8351 - precision: 0.6578 - recall: 0.6648 - val_accuracy: 0.7183 - val_auc: 0.7498 - val_loss: 0.7866 - val_precision: 0.6937 - val_recall: 0.6681 - learning_rate: 3.0000e-05
# Epoch 24/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6825 - auc: 0.6961 - loss: 0.8544 - precision: 0.6513 - recall: 0.6479
# Epoch 24: val_auc improved from 0.74980 to 0.75092, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 17s 810ms/step - accuracy: 0.6828 - auc: 0.6965 - loss: 0.8540 - precision: 0.6511 - recall: 0.6480 - val_accuracy: 0.7035 - val_auc: 0.7509 - val_loss: 0.7873 - val_precision: 0.6995 - val_recall: 0.6696 - learning_rate: 3.0000e-05
# Epoch 25/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.6900 - auc: 0.6947 - loss: 0.8542 - precision: 0.6247 - recall: 0.6402
# Epoch 25: val_auc improved from 0.75092 to 0.75482, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 635ms/step - accuracy: 0.6907 - auc: 0.6952 - loss: 0.8537 - precision: 0.6252 - recall: 0.6407 - val_accuracy: 0.7168 - val_auc: 0.7548 - val_loss: 0.7840 - val_precision: 0.6997 - val_recall: 0.6667 - learning_rate: 3.0000e-05
# Epoch 26/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.6693 - auc: 0.7014 - loss: 0.8495 - precision: 0.6591 - recall: 0.6601
# Epoch 26: val_auc improved from 0.75482 to 0.75784, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 650ms/step - accuracy: 0.6701 - auc: 0.7017 - loss: 0.8494 - precision: 0.6590 - recall: 0.6601 - val_accuracy: 0.7153 - val_auc: 0.7578 - val_loss: 0.7808 - val_precision: 0.7057 - val_recall: 0.6755 - learning_rate: 3.0000e-05
# Epoch 27/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.7073 - auc: 0.7152 - loss: 0.8374 - precision: 0.6446 - recall: 0.6606
# Epoch 27: val_auc improved from 0.75784 to 0.75955, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 638ms/step - accuracy: 0.7068 - auc: 0.7148 - loss: 0.8381 - precision: 0.6444 - recall: 0.6601 - val_accuracy: 0.7124 - val_auc: 0.7596 - val_loss: 0.7802 - val_precision: 0.7040 - val_recall: 0.6667 - learning_rate: 3.0000e-05
# Epoch 28/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6989 - auc: 0.6876 - loss: 0.8783 - precision: 0.6313 - recall: 0.6451
# Epoch 28: val_auc did not improve from 0.75955
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 575ms/step - accuracy: 0.6999 - auc: 0.6889 - loss: 0.8765 - precision: 0.6320 - recall: 0.6460 - val_accuracy: 0.7065 - val_auc: 0.7570 - val_loss: 0.7834 - val_precision: 0.7031 - val_recall: 0.6637 - learning_rate: 3.0000e-05
# Epoch 29/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.7176 - auc: 0.7197 - loss: 0.8312 - precision: 0.6565 - recall: 0.6620
# Epoch 29: val_auc improved from 0.75955 to 0.75962, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 674ms/step - accuracy: 0.7181 - auc: 0.7203 - loss: 0.8303 - precision: 0.6571 - recall: 0.6623 - val_accuracy: 0.7227 - val_auc: 0.7596 - val_loss: 0.7820 - val_precision: 0.7108 - val_recall: 0.6814 - learning_rate: 3.0000e-05
# Epoch 30/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.7247 - auc: 0.7595 - loss: 0.7872 - precision: 0.7047 - recall: 0.6788
# Epoch 30: val_auc improved from 0.75962 to 0.76278, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 16s 753ms/step - accuracy: 0.7239 - auc: 0.7587 - loss: 0.7882 - precision: 0.7035 - recall: 0.6778 - val_accuracy: 0.7168 - val_auc: 0.7628 - val_loss: 0.7797 - val_precision: 0.7141 - val_recall: 0.6740 - learning_rate: 3.0000e-05
# Epoch 31/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.7649 - auc: 0.7807 - loss: 0.7567 - precision: 0.7153 - recall: 0.7178
# Epoch 31: val_auc improved from 0.76278 to 0.76703, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 633ms/step - accuracy: 0.7644 - auc: 0.7802 - loss: 0.7575 - precision: 0.7146 - recall: 0.7175 - val_accuracy: 0.7139 - val_auc: 0.7670 - val_loss: 0.7753 - val_precision: 0.7250 - val_recall: 0.6844 - learning_rate: 3.0000e-05
# Epoch 32/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.6983 - auc: 0.7110 - loss: 0.8579 - precision: 0.6448 - recall: 0.6678
# Epoch 32: val_auc improved from 0.76703 to 0.76982, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - accuracy: 0.6992 - auc: 0.7119 - loss: 0.8563 - precision: 0.6455 - recall: 0.6681 - val_accuracy: 0.7198 - val_auc: 0.7698 - val_loss: 0.7733 - val_precision: 0.7237 - val_recall: 0.6991 - learning_rate: 3.0000e-05
# Epoch 33/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.7413 - auc: 0.7702 - loss: 0.7754 - precision: 0.7098 - recall: 0.6987
# Epoch 33: val_auc improved from 0.76982 to 0.77317, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 640ms/step - accuracy: 0.7404 - auc: 0.7697 - loss: 0.7760 - precision: 0.7090 - recall: 0.6987 - val_accuracy: 0.7301 - val_auc: 0.7732 - val_loss: 0.7704 - val_precision: 0.7219 - val_recall: 0.7006 - learning_rate: 3.0000e-05
# Epoch 34/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.7114 - auc: 0.7635 - loss: 0.7830 - precision: 0.7126 - recall: 0.6964
# Epoch 34: val_auc improved from 0.77317 to 0.77562, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 657ms/step - accuracy: 0.7125 - auc: 0.7641 - loss: 0.7824 - precision: 0.7127 - recall: 0.6969 - val_accuracy: 0.7316 - val_auc: 0.7756 - val_loss: 0.7685 - val_precision: 0.7252 - val_recall: 0.7006 - learning_rate: 3.0000e-05
# Epoch 35/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.7492 - auc: 0.7749 - loss: 0.7680 - precision: 0.7064 - recall: 0.6960
# Epoch 35: val_auc improved from 0.77562 to 0.77742, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 652ms/step - accuracy: 0.7491 - auc: 0.7744 - loss: 0.7687 - precision: 0.7058 - recall: 0.6957 - val_accuracy: 0.7330 - val_auc: 0.7774 - val_loss: 0.7673 - val_precision: 0.7336 - val_recall: 0.7109 - learning_rate: 3.0000e-05
# Epoch 36/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.7396 - auc: 0.7823 - loss: 0.7622 - precision: 0.7234 - recall: 0.7071
# Epoch 36: val_auc did not improve from 0.77742
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 564ms/step - accuracy: 0.7388 - auc: 0.7813 - loss: 0.7637 - precision: 0.7219 - recall: 0.7068 - val_accuracy: 0.7271 - val_auc: 0.7773 - val_loss: 0.7675 - val_precision: 0.7262 - val_recall: 0.7080 - learning_rate: 3.0000e-05
# Epoch 37/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.7801 - auc: 0.7965 - loss: 0.7345 - precision: 0.7036 - recall: 0.7194
# Epoch 37: val_auc did not improve from 0.77742
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 562ms/step - accuracy: 0.7791 - auc: 0.7955 - loss: 0.7361 - precision: 0.7029 - recall: 0.7185 - val_accuracy: 0.7227 - val_auc: 0.7771 - val_loss: 0.7672 - val_precision: 0.7284 - val_recall: 0.6962 - learning_rate: 3.0000e-05
# Epoch 38/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.7574 - auc: 0.7767 - loss: 0.7754 - precision: 0.7120 - recall: 0.7049
# Epoch 38: val_auc improved from 0.77742 to 0.77874, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 893ms/step - accuracy: 0.7572 - auc: 0.7768 - loss: 0.7750 - precision: 0.7118 - recall: 0.7052 - val_accuracy: 0.7345 - val_auc: 0.7787 - val_loss: 0.7667 - val_precision: 0.7266 - val_recall: 0.6976 - learning_rate: 3.0000e-05
# Epoch 39/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.7371 - auc: 0.7559 - loss: 0.7924 - precision: 0.6807 - recall: 0.6968
# Epoch 39: val_auc improved from 0.77874 to 0.78099, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 663ms/step - accuracy: 0.7369 - auc: 0.7563 - loss: 0.7920 - precision: 0.6811 - recall: 0.6968 - val_accuracy: 0.7375 - val_auc: 0.7810 - val_loss: 0.7657 - val_precision: 0.7324 - val_recall: 0.7065 - learning_rate: 3.0000e-05
# Epoch 40/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.7360 - auc: 0.7690 - loss: 0.7804 - precision: 0.6942 - recall: 0.7207
# Epoch 40: val_auc improved from 0.78099 to 0.78187, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 651ms/step - accuracy: 0.7365 - auc: 0.7691 - loss: 0.7802 - precision: 0.6945 - recall: 0.7202 - val_accuracy: 0.7360 - val_auc: 0.7819 - val_loss: 0.7670 - val_precision: 0.7316 - val_recall: 0.7035 - learning_rate: 3.0000e-05
# Epoch 41/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.7625 - auc: 0.7804 - loss: 0.7709 - precision: 0.7151 - recall: 0.6922
# Epoch 41: val_auc did not improve from 0.78187
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 568ms/step - accuracy: 0.7623 - auc: 0.7804 - loss: 0.7708 - precision: 0.7153 - recall: 0.6925 - val_accuracy: 0.7330 - val_auc: 0.7798 - val_loss: 0.7716 - val_precision: 0.7318 - val_recall: 0.6962 - learning_rate: 3.0000e-05
# Epoch 42/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.7322 - auc: 0.7684 - loss: 0.7732 - precision: 0.6912 - recall: 0.6961
# Epoch 42: val_auc did not improve from 0.78187
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 574ms/step - accuracy: 0.7329 - auc: 0.7690 - loss: 0.7725 - precision: 0.6920 - recall: 0.6966 - val_accuracy: 0.7301 - val_auc: 0.7787 - val_loss: 0.7736 - val_precision: 0.7333 - val_recall: 0.6976 - learning_rate: 3.0000e-05
# Epoch 43/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.7658 - auc: 0.7953 - loss: 0.7461 - precision: 0.7247 - recall: 0.7443
# Epoch 43: val_auc improved from 0.78187 to 0.78283, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 931ms/step - accuracy: 0.7658 - auc: 0.7953 - loss: 0.7460 - precision: 0.7245 - recall: 0.7443 - val_accuracy: 0.7360 - val_auc: 0.7828 - val_loss: 0.7665 - val_precision: 0.7361 - val_recall: 0.7035 - learning_rate: 3.0000e-05
# Epoch 44/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.7868 - auc: 0.8106 - loss: 0.7154 - precision: 0.7306 - recall: 0.7163
# Epoch 44: val_auc improved from 0.78283 to 0.78410, saving model to best_densenet_cbis.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 636ms/step - accuracy: 0.7850 - auc: 0.8096 - loss: 0.7170 - precision: 0.7296 - recall: 0.7161 - val_accuracy: 0.7301 - val_auc: 0.7841 - val_loss: 0.7654 - val_precision: 0.7373 - val_recall: 0.7080 - learning_rate: 3.0000e-05
# Epoch 45/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.7609 - auc: 0.7935 - loss: 0.7414 - precision: 0.7296 - recall: 0.7403
# Epoch 45: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 546ms/step - accuracy: 0.7611 - auc: 0.7940 - loss: 0.7409 - precision: 0.7300 - recall: 0.7402 - val_accuracy: 0.7316 - val_auc: 0.7838 - val_loss: 0.7663 - val_precision: 0.7327 - val_recall: 0.7035 - learning_rate: 3.0000e-05
# Epoch 46/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.7668 - auc: 0.7723 - loss: 0.7740 - precision: 0.7023 - recall: 0.6984
# Epoch 46: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 566ms/step - accuracy: 0.7673 - auc: 0.7731 - loss: 0.7730 - precision: 0.7025 - recall: 0.6994 - val_accuracy: 0.7242 - val_auc: 0.7825 - val_loss: 0.7686 - val_precision: 0.7275 - val_recall: 0.7050 - learning_rate: 3.0000e-05
# Epoch 47/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7694 - auc: 0.8060 - loss: 0.7244 - precision: 0.7326 - recall: 0.7040
# Epoch 47: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 555ms/step - accuracy: 0.7691 - auc: 0.8057 - loss: 0.7250 - precision: 0.7323 - recall: 0.7042 - val_accuracy: 0.7271 - val_auc: 0.7827 - val_loss: 0.7705 - val_precision: 0.7285 - val_recall: 0.7006 - learning_rate: 3.0000e-05
# Epoch 48/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.7641 - auc: 0.7958 - loss: 0.7394 - precision: 0.7154 - recall: 0.7311
# Epoch 48: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 573ms/step - accuracy: 0.7638 - auc: 0.7955 - loss: 0.7401 - precision: 0.7152 - recall: 0.7306 - val_accuracy: 0.7286 - val_auc: 0.7831 - val_loss: 0.7713 - val_precision: 0.7260 - val_recall: 0.7035 - learning_rate: 3.0000e-05
# Epoch 49/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7847 - auc: 0.8120 - loss: 0.7231 - precision: 0.7334 - recall: 0.7359
# Epoch 49: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 564ms/step - accuracy: 0.7835 - auc: 0.8115 - loss: 0.7239 - precision: 0.7328 - recall: 0.7359 - val_accuracy: 0.7271 - val_auc: 0.7833 - val_loss: 0.7719 - val_precision: 0.7284 - val_recall: 0.7080 - learning_rate: 3.0000e-05
# Epoch 50/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8056 - auc: 0.8222 - loss: 0.7094 - precision: 0.7459 - recall: 0.7457
# Epoch 50: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 556ms/step - accuracy: 0.8044 - auc: 0.8215 - loss: 0.7103 - precision: 0.7453 - recall: 0.7452 - val_accuracy: 0.7286 - val_auc: 0.7825 - val_loss: 0.7723 - val_precision: 0.7317 - val_recall: 0.7080 - learning_rate: 9.0000e-06
# Epoch 51/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.7847 - auc: 0.8143 - loss: 0.7224 - precision: 0.7479 - recall: 0.7336
# Epoch 51: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 552ms/step - accuracy: 0.7844 - auc: 0.8144 - loss: 0.7224 - precision: 0.7476 - recall: 0.7341 - val_accuracy: 0.7257 - val_auc: 0.7825 - val_loss: 0.7702 - val_precision: 0.7319 - val_recall: 0.7006 - learning_rate: 9.0000e-06
# Epoch 52/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.7655 - auc: 0.8013 - loss: 0.7373 - precision: 0.7360 - recall: 0.7067
# Epoch 52: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - accuracy: 0.7666 - auc: 0.8018 - loss: 0.7368 - precision: 0.7359 - recall: 0.7076 - val_accuracy: 0.7286 - val_auc: 0.7829 - val_loss: 0.7698 - val_precision: 0.7335 - val_recall: 0.7065 - learning_rate: 9.0000e-06
# Epoch 53/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.7841 - auc: 0.8109 - loss: 0.7271 - precision: 0.7359 - recall: 0.7379
# Epoch 53: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 571ms/step - accuracy: 0.7842 - auc: 0.8112 - loss: 0.7265 - precision: 0.7362 - recall: 0.7379 - val_accuracy: 0.7242 - val_auc: 0.7833 - val_loss: 0.7685 - val_precision: 0.7301 - val_recall: 0.7021 - learning_rate: 9.0000e-06
# Epoch 54/60
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8125 - auc: 0.8405 - loss: 0.6800 - precision: 0.7610 - recall: 0.7505
# Epoch 54: val_auc did not improve from 0.78410
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 573ms/step - accuracy: 0.8116 - auc: 0.8399 - loss: 0.6808 - precision: 0.7601 - recall: 0.7501 - val_accuracy: 0.7271 - val_auc: 0.7827 - val_loss: 0.7685 - val_precision: 0.7323 - val_recall: 0.7021 - learning_rate: 9.0000e-06
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 489ms/step

# %% [markdown]
# # Evaluation

# %%
print(metrics)
# Out:
# {'test_accuracy': 0.7352941036224365, 'test_loss': 0.7497508525848389, 'test_precision': 0.7564102411270142, 'test_recall': 0.6941176652908325, 'test_f1_score': 0.735496471078789, 'test_auc': 0.7938019037246704}

# %%
def confusion_matrix_plot(test, y_predict):
  y_pred = np.argmax(y_predict, axis=1)

  # get class indices and labels
  class_indices = test.class_indices
  classes = list(class_indices.keys())

  # compute confusion matrix
  cm = confusion_matrix(test.classes, y_pred)

  plt.figure(figsize=(10, 10))
  plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title('Confusion Matrix')
  plt.colorbar()

  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  threshold = cm.max() / 2.0
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(
          j, i, f"{cm[i, j]}",
          horizontalalignment='center',
          color='white' if cm[i, j] > threshold else 'black'
      )

  plt.tight_layout()
  plt.ylabel('True Label')
  plt.xlabel('Predicted Label')
  plt.show()

y_prediction = model.predict(augmented_test)
confusion_matrix_plot(augmented_test, y_prediction)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step

# %%
# Get the true labels and predicted probabilities for the positive class (MALIGNANT)
y_true = augmented_test.classes
y_pred_prob = y_prediction[:, 1]  # Get probabilities for the 'MALIGNANT' class

# Calculate the AUC
auc_score = auc(roc_curve(y_true, y_pred_prob)[0], roc_curve(y_true, y_pred_prob)[1])
print(f'AUC: {auc_score:.4f}')

# Plot the ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC: 0.7949

# %% [markdown]
# # Classification Report

# %%
# Visualize model history
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('training / validation accuracies')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('ReLU training / validation loss values')
plt.ylabel('Loss value')
plt.xlabel('Epoch')
plt.show()
